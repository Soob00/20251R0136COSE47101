# %% [markdown]
# <a href="https://colab.research.google.com/github/Soob00/20251R0136COSE47101/blob/dataset2_pattern-mining/patternming/notebooks/dataset2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/2025 Data Science Project/원핫인코딩_결측치가 포함된 모든 행 제거.csv'

data = pd.read_csv(file_path, encoding="utf-8")

# 불러온 csv 파일 읽기
print(data.head())
# Out:
#    YEAR       AGE  EDUC  GENDER  SPHSERVICE  CMPSERVICE  OPISERVICE  \
# 0  2022  0.461538  0.50       1           0           1           0
# 1  2022  1.000000  0.75       0           1           1           0
# 2  2022  0.615385  1.00       0           0           1           1
# 3  2022  0.615385  1.00       0           0           1           1
# 4  2022  0.846154  0.50       0           0           1           0
#
#    RTCSERVICE  IJSSERVICE  MH1  ...  LIVARAG_3  DIVISION_1  DIVISION_2  \
# 0           0           0    7  ...      False       False       False
# 1           0           0   11  ...       True       False       False
# 2           0           0    7  ...      False       False       False
# 3           0           0    7  ...      False       False       False
# 4           0           0    6  ...      False       False       False
#
#    DIVISION_3  DIVISION_4  DIVISION_5  DIVISION_6  DIVISION_7  DIVISION_8  \
# 0       False       False       False        True       False       False
# 1       False       False       False        True       False       False
# 2       False       False       False        True       False       False
# 3       False       False       False        True       False       False
# 4       False       False       False        True       False       False
#
#    DIVISION_9
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#
# [5 rows x 77 columns]

# %%
import pandas as pd
data = pd.read_csv('/content/원핫인코딩_결측치가 포함된 모든 행 제거.csv')

# %% [markdown]
# # **STEP1: 질환 간의 동시 발생 패턴 탐색**
# 예: "우울증이 있는 사람은 불안장애도 함께 겪는 경우가 많다"
#
# 방법: FP-Growth로 질환 간 조합 찾기**
#
# - **사용 칼럼**: TRAUSTRE, ANXIETY, ADHD, CONDUCT, DELIRDEM, BIPOLAR, DEPRESS, ODD, PDD, PERSON, SCHIZO, ALCSUB, OTHERDIS, SUB.
# - **이유**: 이 변수들은 질병의 존재 여부를 나타내며, 질환 간 동시 발생 패턴(예: DEPRESS와 ANXIETY의 조합)을 찾는 데 적합.

# %% [markdown]
# ---

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules

# 1. 결측값이 있는 행 제거
data_cleaned = data.dropna()

# 2. 질병 변수만 추출
disease_columns = ['TRAUSTREFLG', 'ANXIETYFLG', 'ADHDFLG', 'CONDUCTFLG', 'DELIRDEMFLG', 'BIPOLARFLG', 'DEPRESSFLG', 'ODDFLG', 'PDDFLG', 'PERSONFLG', 'SCHIZOFLG', 'ALCSUBFLG', 'OTHERDISFLG', 'SUB_1', 'SUB_2', 'SUB_3', 'SUB_4', 'SUB_5', 'SUB_6', 'SUB_7', 'SUB_8', 'SUB_9', 'SUB_10', 'SUB_11', 'SUB_12', 'SUB_13']
disease_data = data_cleaned[disease_columns]

# FP-Growth 알고리즘 적용하여 자주 등장하는 항목 집합 찾기
#너무 희귀한 변수 제거
selected_columns = disease_data.columns[disease_data.sum() >= 5000]
disease_data_filtered = disease_data[selected_columns]
# 3. minimum support: 0.01 -> 안들어가는 변수가 있어서 0.005로 변경
frequent_itemsets = fpgrowth(disease_data_filtered, min_support=0.005, use_colnames=True)

# 4. minimum lift(향상도) 1.2 이상인 연관 규칙 생성
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.2)

# 5. 결과 출력
print("Frequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
print(rules)
# Out:
# /usr/local/lib/python3.11/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Frequent Itemsets:
#      support                  itemsets
# 0   0.350759              (DEPRESSFLG)
# 1   0.159832               (SCHIZOFLG)
# 2   0.240187              (ANXIETYFLG)
# 3   0.190046             (TRAUSTREFLG)
# 4   0.015345                  (SUB_11)
# ..       ...                       ...
# 69  0.018815   (ALCSUBFLG, DEPRESSFLG)
# 70  0.012218   (ALCSUBFLG, ANXIETYFLG)
# 71  0.011109  (TRAUSTREFLG, ALCSUBFLG)
# 72  0.011383    (SCHIZOFLG, ALCSUBFLG)
# 73  0.011185   (ALCSUBFLG, BIPOLARFLG)
#
# [74 rows x 2 columns]
#
# Association Rules:
#                   antecedents                consequents  antecedent support  \
# 0   (TRAUSTREFLG, DEPRESSFLG)               (ANXIETYFLG)            0.053054
# 1   (TRAUSTREFLG, ANXIETYFLG)               (DEPRESSFLG)            0.035378
# 2                (DEPRESSFLG)  (TRAUSTREFLG, ANXIETYFLG)            0.350759
# 3                (ANXIETYFLG)  (TRAUSTREFLG, DEPRESSFLG)            0.240187
# 4                     (SUB_8)               (BIPOLARFLG)            0.025109
# 5                (BIPOLARFLG)                    (SUB_8)            0.159783
# 6                 (SCHIZOFLG)                    (SUB_8)            0.159832
# 7                     (SUB_8)                (SCHIZOFLG)            0.025109
# 8               (TRAUSTREFLG)                    (SUB_8)            0.190046
# 9                     (SUB_8)              (TRAUSTREFLG)            0.025109
# 10                    (SUB_8)                (ALCSUBFLG)            0.025109
# 11                (ALCSUBFLG)                    (SUB_8)            0.064401
# 12               (DEPRESSFLG)                    (SUB_4)            0.350759
# 13                    (SUB_4)               (DEPRESSFLG)            0.042193
# 14               (BIPOLARFLG)                    (SUB_4)            0.159783
# 15                    (SUB_4)               (BIPOLARFLG)            0.042193
# 16                (ALCSUBFLG)                    (SUB_4)            0.064401
# 17                    (SUB_4)                (ALCSUBFLG)            0.042193
# 18   (DEPRESSFLG, ANXIETYFLG)                    (SUB_4)            0.098357
# 19        (DEPRESSFLG, SUB_4)               (ANXIETYFLG)            0.017906
# 20        (ANXIETYFLG, SUB_4)               (DEPRESSFLG)            0.011672
# 21               (DEPRESSFLG)        (ANXIETYFLG, SUB_4)            0.350759
# 22               (ANXIETYFLG)        (DEPRESSFLG, SUB_4)            0.240187
# 23                    (SUB_4)   (DEPRESSFLG, ANXIETYFLG)            0.042193
# 24                (PERSONFLG)               (BIPOLARFLG)            0.036234
# 25               (BIPOLARFLG)                (PERSONFLG)            0.159783
# 26              (TRAUSTREFLG)                (PERSONFLG)            0.190046
# 27                (PERSONFLG)              (TRAUSTREFLG)            0.036234
# 28                  (ADHDFLG)              (OTHERDISFLG)            0.050475
# 29              (OTHERDISFLG)                  (ADHDFLG)            0.113109
# 30                    (SUB_6)                (ALCSUBFLG)            0.018011
# 31                (ALCSUBFLG)                    (SUB_6)            0.064401
# 32                    (SUB_7)               (BIPOLARFLG)            0.027110
# 33               (BIPOLARFLG)                    (SUB_7)            0.159783
# 34              (OTHERDISFLG)                   (PDDFLG)            0.113109
# 35                   (PDDFLG)              (OTHERDISFLG)            0.016260
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.240187  0.016124    0.303922  1.265354               1.0
# 1             0.350759  0.016124    0.455770  1.299381               1.0
# 2             0.035378  0.016124    0.045969  1.299381               1.0
# 3             0.053054  0.016124    0.067132  1.265354               1.0
# 4             0.159783  0.005121    0.203956  1.276453               1.0
# 5             0.025109  0.005121    0.032051  1.276453               1.0
# 6             0.025109  0.005481    0.034292  1.365722               1.0
# 7             0.159832  0.005481    0.218286  1.365722               1.0
# 8             0.025109  0.005909    0.031091  1.238242               1.0
# 9             0.190046  0.005909    0.235323  1.238242               1.0
# 10            0.064401  0.007843    0.312353  4.850135               1.0
# 11            0.025109  0.007843    0.121784  4.850135               1.0
# 12            0.042193  0.017906    0.051049  1.209896               1.0
# 13            0.350759  0.017906    0.424383  1.209896               1.0
# 14            0.042193  0.008630    0.054009  1.280051               1.0
# 15            0.159783  0.008630    0.204530  1.280051               1.0
# 16            0.042193  0.008103    0.125815  2.981915               1.0
# 17            0.064401  0.008103    0.192038  2.981915               1.0
# 18            0.042193  0.005832    0.059296  1.405352               1.0
# 19            0.240187  0.005832    0.325710  1.356070               1.0
# 20            0.350759  0.005832    0.499664  1.424521               1.0
# 21            0.011672  0.005832    0.016627  1.424521               1.0
# 22            0.017906  0.005832    0.024282  1.356070               1.0
# 23            0.098357  0.005832    0.138226  1.405352               1.0
# 24            0.159783  0.009714    0.268076  1.677748               1.0
# 25            0.036234  0.009714    0.060792  1.677748               1.0
# 26            0.036234  0.009258    0.048714  1.344414               1.0
# 27            0.190046  0.009258    0.255500  1.344414               1.0
# 28            0.113109  0.008062    0.159716  1.412060               1.0
# 29            0.050475  0.008062    0.071273  1.412060               1.0
# 30            0.064401  0.005064    0.281140  4.365469               1.0
# 31            0.018011  0.005064    0.078628  4.365469               1.0
# 32            0.159783  0.005683    0.209635  1.311997               1.0
# 33            0.027110  0.005683    0.035568  1.311997               1.0
# 34            0.016260  0.006873    0.060767  3.737185               1.0
# 35            0.113109  0.006873    0.422708  3.737185               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.003381    1.091562       0.221457  0.058185   0.083882    0.185527
# 1   0.003715    1.192953       0.238853  0.043577   0.161744    0.250870
# 2   0.003715    1.011102       0.354880  0.043577   0.010980    0.250870
# 3   0.003381    1.015091       0.275999  0.058185   0.014867    0.185527
# 4   0.001109    1.055490       0.222157  0.028487   0.052573    0.118003
# 5   0.001109    1.007171       0.257766  0.028487   0.007120    0.118003
# 6   0.001468    1.009509       0.318730  0.030542   0.009420    0.126289
# 7   0.001468    1.074777       0.274684  0.030542   0.069574    0.126289
# 8   0.001137    1.006174       0.237548  0.028238   0.006136    0.133207
# 9   0.001137    1.059210       0.197359  0.028238   0.055901    0.133207
# 10  0.006226    1.360580       0.814266  0.096036   0.265019    0.217068
# 11  0.006226    1.110080       0.848462  0.096036   0.099164    0.217068
# 12  0.003106    1.009333       0.267209  0.047743   0.009246    0.237716
# 13  0.003106    1.127903       0.181125  0.047743   0.113399    0.237716
# 14  0.001888    1.012491       0.260386  0.044633   0.012337    0.129270
# 15  0.001888    1.056253       0.228418  0.044633   0.053257    0.129270
# 16  0.005385    1.095658       0.710395  0.082267   0.087306    0.158926
# 17  0.005385    1.157974       0.693924  0.082267   0.136423    0.158926
# 18  0.001682    1.018181       0.319899  0.043292   0.017856    0.098761
# 19  0.001531    1.126835       0.267363  0.023119   0.112559    0.174996
# 20  0.001738    1.297609       0.301529  0.016355   0.229352    0.258146
# 21  0.001738    1.005039       0.459013  0.016355   0.005014    0.258146
# 22  0.001531    1.006534       0.345579  0.023119   0.006492    0.174996
# 23  0.001682    1.046264       0.301140  0.043292   0.044218    0.098761
# 24  0.003924    1.147956       0.419150  0.052138   0.128886    0.164434
# 25  0.003924    1.026147       0.480784  0.052138   0.025481    0.164434
# 26  0.002372    1.013119       0.316291  0.042659   0.012949    0.152107
# 27  0.002372    1.087917       0.265813  0.042659   0.080812    0.152107
# 28  0.002353    1.055466       0.307327  0.051836   0.052552    0.115495
# 29  0.002353    1.022395       0.329031  0.051836   0.021904    0.115495
# 30  0.003904    1.301503       0.785070  0.065466   0.231658    0.179884
# 31  0.003904    1.065789       0.823996  0.065466   0.061728    0.179884
# 32  0.001351    1.063074       0.244429  0.031362   0.059332    0.122601
# 33  0.001351    1.008770       0.283026  0.031362   0.008694    0.122601
# 34  0.005034    1.047386       0.825827  0.056110   0.045242    0.241737
# 35  0.005034    1.536296       0.744525  0.056110   0.349084    0.241737

# %% [markdown]
# # FP-Growth 분석 결과 확인
#
# **빈번한 질환 조합 (Frequent Itemsets)**
#   (최소 지지도(1%) 이상인 조합들만 나열함)
#
# - 가장 빈번한 단일 질환: DEPRESSFLG (우울증 관련 질환)이 35.08%의 지지도(support)로 가장 자주 나타남
# - 주요 2개 조합: DEPRESSFLG와 ANXIETYFLG (불안 관련 질환)의 조합이 9.84%로 가장 흔한 쌍임
# - 3개 조합: DEPRESSFLG, TRAUSTREFLG (외상 관련 질환), ANXIETYFLG가 1.61%의 지지도를 보임
#
# **연관 규칙 (Association Rules)**
#   (모든 규칙은 리프트 1.2 이상으로 필터링되어, 의미 있는 연관성만 포함함)
# - 규칙 1: DEPRESSFLG와 TRAUSTREFLG가 있을 때 ANXIETYFLG가 나타날 확률(confidence)은 30.39%, 리프트(lift)는 1.27로 양의 상관관계를 보임
# - 규칙 2: TRAUSTREFLG와 ANXIETYFLG가 있을 때 DEPRESSFLG가 나타날 확률은 45.58%, 리프트는 1.30으로 강한 연관성을 시사함
#
# **CONCLUSION: DEPRESSFLG, ANXIETYFLG, TRAUSTREFLG 같은 질환들이 자주 함께 나타남**

# %% [markdown]
# ---
# # **STEP 2: 질환+배경 변수의 연관 규칙**
#  **사용 칼럼**:
#  - 질환: 위와 동일
#  - 배경: (AGE, EDUC)순서형이라서 생략, ETHNIC, RACE, GENDER, MARSTAT, SMISED, SAP, EMPLOY, DETNLF, VETERAN, LIVARAG.
#
# - **이유**: 질환과 배경 변수 간 연관성을 찾기 위해 모두 포함(예: "DEPRESS + EMPLOY=실업 → PTSD").
# - **방법**: FP-Growth

# %%
# 1. 결측값이 있는 행 제거
data_cleaned = data.dropna()

# 2. 배경 변수 추출
background_columns = [
    "GENDER", "SPHSERVICE", "CMPSERVICE", "OPISERVICE", "RTCSERVICE", "IJSSERVICE",
    "RACE_2", "RACE_3", "RACE_4", "RACE_5", "RACE_6",
    "ETHNIC_2", "ETHNIC_3", "ETHNIC_4",
    "MARSTAT_2", "MARSTAT_3", "MARSTAT_4",
    "SMISED_2", "SMISED_3",
    "DETNLF_2", "DETNLF_3", "DETNLF_4", "DETNLF_5", "DETNLF_NotApplicable",
    "LIVARAG_2", "LIVARAG_3"
]

background_data = data_cleaned[background_columns]

# Combine all columns
all_columns = list(disease_data.columns) + list(background_data.columns)

# Extract relevant data
data_all = data_cleaned[all_columns]
data_all = (data_all > 0).astype(bool)

# Check for NaN values
print("NaN counts before processing:")
print(data_all.isna().sum())


# NaN 은 0 대체
data_all = data_all.fillna(0)

# Verify no NaN values remain
print("\nNaN counts after processing:")
print(data_all.isna().sum())

# Check number of rows
print("\nNumber of rows in data_all:", len(data_all))

# Ensure data is binary
print("\nUnique values in each column:")
for col in data_all.columns:
    print(f"{col}: {data_all[col].unique()}")

# Apply FP-Growth
if len(data_all) > 0:
    frequent_itemsets = fpgrowth(data_all, min_support=0.01, use_colnames=True)

    # Generate association rules
    rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.2)

    # Filter rules
    disease_to_background_rules = rules[rules['antecedents'].apply(lambda x: any(item in disease_columns for item in x)) &
                                        rules['consequents'].apply(lambda x: any(item in background_columns for item in x))]
    background_to_disease_rules = rules[rules['antecedents'].apply(lambda x: any(item in background_columns for item in x)) &
                                        rules['consequents'].apply(lambda x: any(item in disease_columns for item in x))]

    # Output results
    print("\nDisease to Background Rules:")
    print(disease_to_background_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
    print("\nBackground to Disease Rules:")
    print(background_to_disease_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

    # Save rules
    disease_to_background_rules.to_csv('disease_to_background_rules.csv', index=False)
    background_to_disease_rules.to_csv('background_to_disease_rules.csv', index=False)
else:
    print("Error: DataFrame is empty after processing.")
# Out:
# NaN counts before processing:
# TRAUSTREFLG             0
# ANXIETYFLG              0
# ADHDFLG                 0
# CONDUCTFLG              0
# DELIRDEMFLG             0
# BIPOLARFLG              0
# DEPRESSFLG              0
# ODDFLG                  0
# PDDFLG                  0
# PERSONFLG               0
# SCHIZOFLG               0
# ALCSUBFLG               0
# OTHERDISFLG             0
# SUB_1                   0
# SUB_2                   0
# SUB_3                   0
# SUB_4                   0
# SUB_5                   0
# SUB_6                   0
# SUB_7                   0
# SUB_8                   0
# SUB_9                   0
# SUB_10                  0
# SUB_11                  0
# SUB_12                  0
# SUB_13                  0
# GENDER                  0
# SPHSERVICE              0
# CMPSERVICE              0
# OPISERVICE              0
# RTCSERVICE              0
# IJSSERVICE              0
# RACE_2                  0
# RACE_3                  0
# RACE_4                  0
# RACE_5                  0
# RACE_6                  0
# ETHNIC_2                0
# ETHNIC_3                0
# ETHNIC_4                0
# MARSTAT_2               0
# MARSTAT_3               0
# MARSTAT_4               0
# SMISED_2                0
# SMISED_3                0
# DETNLF_2                0
# DETNLF_3                0
# DETNLF_4                0
# DETNLF_5                0
# DETNLF_NotApplicable    0
# LIVARAG_2               0
# LIVARAG_3               0
# dtype: int64
#
# NaN counts after processing:
# TRAUSTREFLG             0
# ANXIETYFLG              0
# ADHDFLG                 0
# CONDUCTFLG              0
# DELIRDEMFLG             0
# BIPOLARFLG              0
# DEPRESSFLG              0
# ODDFLG                  0
# PDDFLG                  0
# PERSONFLG               0
# SCHIZOFLG               0
# ALCSUBFLG               0
# OTHERDISFLG             0
# SUB_1                   0
# SUB_2                   0
# SUB_3                   0
# SUB_4                   0
# SUB_5                   0
# SUB_6                   0
# SUB_7                   0
# SUB_8                   0
# SUB_9                   0
# SUB_10                  0
# SUB_11                  0
# SUB_12                  0
# SUB_13                  0
# GENDER                  0
# SPHSERVICE              0
# CMPSERVICE              0
# OPISERVICE              0
# RTCSERVICE              0
# IJSSERVICE              0
# RACE_2                  0
# RACE_3                  0
# RACE_4                  0
# RACE_5                  0
# RACE_6                  0
# ETHNIC_2                0
# ETHNIC_3                0
# ETHNIC_4                0
# MARSTAT_2               0
# MARSTAT_3               0
# MARSTAT_4               0
# SMISED_2                0
# SMISED_3                0
# DETNLF_2                0
# DETNLF_3                0
# DETNLF_4                0
# DETNLF_5                0
# DETNLF_NotApplicable    0
# LIVARAG_2               0
# LIVARAG_3               0
# dtype: int64
#
# Number of rows in data_all: 1147781
#
# Unique values in each column:
# TRAUSTREFLG: [False  True]
# ANXIETYFLG: [False  True]
# ADHDFLG: [False  True]
# CONDUCTFLG: [False  True]
# DELIRDEMFLG: [False  True]
# BIPOLARFLG: [False  True]
# DEPRESSFLG: [ True False]
# ODDFLG: [False  True]
# PDDFLG: [False  True]
# PERSONFLG: [False  True]
# SCHIZOFLG: [ True False]
# ALCSUBFLG: [False  True]
# OTHERDISFLG: [False  True]
# SUB_1: [False  True]
# SUB_2: [False  True]
# SUB_3: [False  True]
# SUB_4: [False  True]
# SUB_5: [False  True]
# SUB_6: [False  True]
# SUB_7: [False  True]
# SUB_8: [False  True]
# SUB_9: [False  True]
# SUB_10: [False  True]
# SUB_11: [False  True]
# SUB_12: [False  True]
# SUB_13: [False  True]
# GENDER: [ True False]
# SPHSERVICE: [False  True]
# CMPSERVICE: [ True False]
# OPISERVICE: [False  True]
# RTCSERVICE: [False  True]
# IJSSERVICE: [False  True]
# RACE_2: [False  True]
# RACE_3: [False  True]
# RACE_4: [ True False]
# RACE_5: [False  True]
# RACE_6: [False  True]
# ETHNIC_2: [False  True]
# ETHNIC_3: [ True False]
# ETHNIC_4: [False  True]
# MARSTAT_2: [ True False]
# MARSTAT_3: [False  True]
# MARSTAT_4: [False  True]
# SMISED_2: [False  True]
# SMISED_3: [False  True]
# DETNLF_2: [False  True]
# DETNLF_3: [False  True]
# DETNLF_4: [False  True]
# DETNLF_5: [False  True]
# DETNLF_NotApplicable: [ True False]
# LIVARAG_2: [ True False]
# LIVARAG_3: [False  True]

# %% [markdown]
# # step 2에서 결측치 때문에 계속 오류가 나는데 아직 왜 그런지 정확하게 파악을 못했어요 그래서 여기서 부터 밑에 까지는 아직 결과 분석을 step 1 처럼 정리 못했음

# %% [markdown]
# # **Step 3: 전략 B - 질환 행렬로 K-Means 클러스터링**
#
# - **사용 데이터**: disease data
# - **이유**: 질환 행렬(바이너리 데이터)을 사용해 환자를 질병 프로필로 군집화.

# %%
import pandas as pd
from sklearn.cluster import KMeans

# K-평균 클러스터링 실행 (초기 클러스터 개수는 5개, 데이터에 따라 조정 가능)
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
clusters = kmeans.fit_predict(disease_data)

# 클러스터 레이블을 데이터프레임에 추가
data['cluster'] = clusters

# 각 클러스터별 질병 변수의 평균으로 요약
cluster_summary = data.groupby('cluster')[disease_columns].mean()
print("Cluster Summary (Mean of Disease Variables):")
print(cluster_summary)

# 클러스터 레이블이 포함된 데이터프레임 저장n_clusters = 5
data.to_csv('clustered_data.csv', index=False)
# Out:
# Cluster Summary (Mean of Disease Variables):
#          TRAUSTREFLG  ANXIETYFLG   ADHDFLG  CONDUCTFLG  DELIRDEMFLG  \
# cluster
# 0           0.358203    0.000000  0.087998    0.016742     0.005432
# 1           0.150272    0.293254  0.033993    0.001979     0.002143
# 2           0.067806    0.085581  0.014430    0.001988     0.005166
# 3           0.158265    0.000000  0.048286    0.002980     0.002242
# 4           0.137748    1.000000  0.064578    0.003425     0.001682
#
#          BIPOLARFLG  DEPRESSFLG    ODDFLG    PDDFLG  PERSONFLG  ...     SUB_4  \
# cluster                                                         ...
# 0          0.000000    0.000000  0.019130  0.035716   0.027879  ...  0.029243
# 1          0.009419    1.000000  0.002974  0.005925   0.032951  ...  0.050392
# 2          0.028642    0.051650  0.001178  0.009175   0.037019  ...  0.040548
# 3          1.000000    0.058911  0.003303  0.008384   0.062172  ...  0.051307
# 4          0.219320    0.000000  0.003465  0.020656   0.035480  ...  0.039806
#
#             SUB_5     SUB_6     SUB_7     SUB_8     SUB_9    SUB_10    SUB_11  \
# cluster
# 0        0.003541  0.010419  0.022028  0.019290  0.006858  0.001129  0.007837
# 1        0.005601  0.018173  0.030702  0.022997  0.012227  0.002146  0.016274
# 2        0.008365  0.024918  0.014129  0.034288  0.015430  0.004199  0.021924
# 3        0.010401  0.025545  0.036339  0.030380  0.014322  0.003865  0.020499
# 4        0.004937  0.017068  0.034720  0.025993  0.011006  0.001743  0.014926
#
#            SUB_12    SUB_13
# cluster
# 0        0.002282  0.004507
# 1        0.003315  0.005104
# 2        0.001765  0.007338
# 3        0.003619  0.005952
# 4        0.003391  0.005500
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 클러스터 설명
#
# - **Cluster 0 (35.82% 외상 관련 질환 비율, ADHD 8.80%)**
#   가장 두드러진 질환:
#
#   TRAUSTREFLG (외상 관련): 35.8%
#
#   ADHDFLG (주의력 결핍): 8.8%
#
#   PDDFLG (발달 지연): 3.6%
#
#   정신질환 핵심 진단은 없음 (ANXIETYFLG, DEPRESSFLG = 0%)
#
#   약물 사용 경향: SUB_7 (2.2%), SUB_6 (1.0%)
#
#   → 정신질환보다는 행동문제/발달지연 관련 이슈가 특징인 군
#
# - **Cluster 1 (우울 + 불안 혼합군, 100% 우울, 29.3% 불안)**
#   DEPRESSION = 100%, ANXIETY = 29.3%
#
#   외상(TRAUSTREFLG): 15%, 양극성(BIPOLARFLG): 0.9%
#
#   → 전형적인 우울증 중심의 고위험 정서장애 군
#   → 불안과 외상도 일부 동반
#
# - **Cluster 2 (가장 경미한 군, 전반적으로 낮은 비율)**
#   DEPRESSFLG: 5.1%, ANXIETYFLG: 8.5%
#
#   나머지 거의 모두 < 3%
#
#   약물 사용도 낮음
#
#   다양한 약물 사용도 동반 (SUB_47 모두 25%)
#
#   → 경증 정신질환 또는 일반 집단에 가까운 안정된 클러스터
#
# - **Cluster 3 (100% BIPOLAR, 일부 DEPRESS)**
#   BIPOLARFLG = 100%, DEPRESSFLG = 5.9%
#
#   PERSONFLG (성격 장애): 6.2%, SCHIZOFLG (조현병): 4.7%
#
#   약물 사용도 SUB_4~8 모두 3% 이상
#
#   → 조울증 중심의 특이 클러스터, 일부 조현병/성격장애 병합
#
# - **Cluster 4 (불안 100%, 일부 ADHD/외상 혼합)**
#   ANXIETYFLG = 100%, TRAUSTREFLG = 13.8%, ADHDFLG = 6.5%
#
#   BIPOLARFLG: 21.9% → 유일하게 조울증도 다소 있음
#   약물 사용도 전체적으로 moderate
#
#   → 불안장애 중심, 일부 외상 + ADHD + 양극성 동반
#
# ###결론 (Conclusion)
# Cluster 1: 우울증 핵심 집단 — 100% DEPRESSFLG, 불안도 병합
#
# Cluster 3: 조울증 고위험군 — 100% BIPOLARFLG, 일부 성격/조현병 포함
#
# Cluster 4: 불안 중심의 복합군 — 100% ANXIETYFLG + 일부 BIPOLAR/ADHD
#
# Cluster 0: 행동/발달 장애 위주 군 — 외상·ADHD 많고 정서장애 없음
#
# Cluster 2: 경증 또는 일반 집단 — 전반적으로 낮은 진단율

# %% [markdown]
# # **Step 4: 전략 B - 클러스터별 배경 조건 확인**
#
# - **사용 칼럼**: AGE, EDUC, ETHNIC, RACE, GENDER, MARSTAT, SMISED, SAP, EMPLOY, DETNLF, VETERAN, LIVARAG.
# - **방법 제안**:
#     - 클러스터별로 배경 변수의 분포를 계산(예: 평균 AGE, EMPLOY 상태 비율).
#     - 시각화(막대그래프, 히스토그램)로 각 클러스터의 배경 특성 비교.
#     - 통계 검정(카이제곱, t-검정)으로 클러스터 간 차이 확인 가능.
# - **이유**: 질병 기반 클러스터에서 배경 변수의 패턴을 역으로 탐색.

# %%
# 클러스터별 배경 변수의 비율 분석
print("Background Variable Proportions by Cluster:")
for col in background_columns:
    cluster_col_summary = data.groupby('cluster')[col].mean()
    print(f"\nProportion of {col} in each cluster:")
    print(cluster_col_summary)


with open('cluster_background_summary.txt', 'w') as f:
    for col in background_columns:
        cluster_col_summary = data.groupby('cluster')[col].mean()
        f.write(f"\nProportion of {col} in each cluster:\n{cluster_col_summary}\n")
# Out:
# Background Variable Proportions by Cluster:
#
# Proportion of AGE in each cluster:
# cluster
# 0    0.511879
# 1    0.573901
# 2    0.646803
# 3    0.601051
# 4    0.541686
# Name: AGE, dtype: float64
#
# Proportion of EDUC in each cluster:
# cluster
# 0    0.679055
# 1    0.736945
# 2    0.701788
# 3    0.750926
# 4    0.744719
# Name: EDUC, dtype: float64
#
# Proportion of GENDER in each cluster:
# cluster
# 0    0.507266
# 1    0.384489
# 2    0.628486
# 3    0.407361
# 4    0.378856
# Name: GENDER, dtype: float64
#
# Proportion of SPHSERVICE in each cluster:
# cluster
# 0    0.003674
# 1    0.005117
# 2    0.019713
# 3    0.008018
# 4    0.003879
# Name: SPHSERVICE, dtype: float64
#
# Proportion of CMPSERVICE in each cluster:
# cluster
# 0    0.960403
# 1    0.951717
# 2    0.938577
# 3    0.949873
# 4    0.984044
# Name: CMPSERVICE, dtype: float64
#
# Proportion of OPISERVICE in each cluster:
# cluster
# 0    0.065429
# 1    0.066721
# 2    0.101899
# 3    0.078855
# 4    0.021402
# Name: OPISERVICE, dtype: float64
#
# Proportion of RTCSERVICE in each cluster:
# cluster
# 0    0.014804
# 1    0.008128
# 2    0.020026
# 3    0.011244
# 4    0.008870
# Name: RTCSERVICE, dtype: float64
#
# Proportion of IJSSERVICE in each cluster:
# cluster
# 0    0.002959
# 1    0.001177
# 2    0.002128
# 3    0.001293
# 4    0.001851
# Name: IJSSERVICE, dtype: float64
#
# Proportion of RACE_2 in each cluster:
# cluster
# 0    0.010228
# 1    0.008162
# 2    0.011493
# 3    0.006529
# 4    0.007670
# Name: RACE_2, dtype: float64
#
# Proportion of RACE_3 in each cluster:
# cluster
# 0    0.202912
# 1    0.211340
# 2    0.385709
# 3    0.204464
# 4    0.135063
# Name: RACE_3, dtype: float64
#
# Proportion of RACE_4 in each cluster:
# cluster
# 0    0.003235
# 1    0.002353
# 2    0.002474
# 3    0.001778
# 4    0.002428
# Name: RACE_4, dtype: float64
#
# Proportion of RACE_5 in each cluster:
# cluster
# 0    0.671411
# 1    0.676779
# 2    0.504004
# 3    0.700314
# 4    0.754721
# Name: RACE_5, dtype: float64
#
# Proportion of RACE_6 in each cluster:
# cluster
# 0    0.094009
# 1    0.085419
# 2    0.082582
# 3    0.073683
# 4    0.084515
# Name: RACE_6, dtype: float64
#
# Proportion of ETHNIC_2 in each cluster:
# cluster
# 0    0.016089
# 1    0.013497
# 2    0.013738
# 3    0.014006
# 4    0.010952
# Name: ETHNIC_2, dtype: float64
#
# Proportion of ETHNIC_3 in each cluster:
# cluster
# 0    0.080120
# 1    0.064362
# 2    0.051086
# 3    0.047885
# 4    0.067657
# Name: ETHNIC_3, dtype: float64
#
# Proportion of ETHNIC_4 in each cluster:
# cluster
# 0    0.879095
# 1    0.899868
# 2    0.920104
# 3    0.923724
# 4    0.896986
# Name: ETHNIC_4, dtype: float64
#
# Proportion of MARSTAT_2 in each cluster:
# cluster
# 0    0.130000
# 1    0.161545
# 2    0.078148
# 3    0.148694
# 4    0.174035
# Name: MARSTAT_2, dtype: float64
#
# Proportion of MARSTAT_3 in each cluster:
# cluster
# 0    0.042240
# 1    0.055096
# 2    0.039538
# 3    0.058103
# 4    0.047584
# Name: MARSTAT_3, dtype: float64
#
# Proportion of MARSTAT_4 in each cluster:
# cluster
# 0    0.127201
# 1    0.187083
# 2    0.146122
# 3    0.203304
# 4    0.165524
# Name: MARSTAT_4, dtype: float64
#
# Proportion of SMISED_2 in each cluster:
# cluster
# 0    0.050193
# 1    0.034975
# 2    0.002787
# 3    0.007808
# 4    0.035588
# Name: SMISED_2, dtype: float64
#
# Proportion of SMISED_3 in each cluster:
# cluster
# 0    0.441388
# 1    0.159059
# 2    0.112671
# 3    0.129017
# 4    0.304282
# Name: SMISED_3, dtype: float64
#
# Proportion of DETNLF_2 in each cluster:
# cluster
# 0    0.155869
# 1    0.078293
# 2    0.017228
# 3    0.033050
# 4    0.093032
# Name: DETNLF_2, dtype: float64
#
# Proportion of DETNLF_3 in each cluster:
# cluster
# 0    0.018889
# 1    0.024644
# 2    0.008248
# 3    0.020633
# 4    0.029193
# Name: DETNLF_3, dtype: float64
#
# Proportion of DETNLF_4 in each cluster:
# cluster
# 0    0.005548
# 1    0.001429
# 2    0.003591
# 3    0.001918
# 4    0.002828
# Name: DETNLF_4, dtype: float64
#
# Proportion of DETNLF_5 in each cluster:
# cluster
# 0    0.060272
# 1    0.069430
# 2    0.109929
# 3    0.082249
# 4    0.070939
# Name: DETNLF_5, dtype: float64
#
# Proportion of DETNLF_NotApplicable in each cluster:
# cluster
# 0    0.619071
# 1    0.648982
# 2    0.497526
# 3    0.645774
# 4    0.637114
# Name: DETNLF_NotApplicable, dtype: float64
#
# Proportion of LIVARAG_2 in each cluster:
# cluster
# 0    0.884463
# 1    0.907531
# 2    0.797783
# 3    0.880695
# 4    0.917967
# Name: LIVARAG_2, dtype: float64
#
# Proportion of LIVARAG_3 in each cluster:
# cluster
# 0    0.057581
# 1    0.037622
# 2    0.124588
# 3    0.052284
# 4    0.043665
# Name: LIVARAG_3, dtype: float64

# %% [markdown]
# ## 결과 해석
#
# ### 설명
#
# **Cluster 0: 외상/행동문제 + 저소득 중간연령군**
#   - SMISED_3 (사회문제 있음): 44.1% → 매우 높음
#
#   - DETNLF_2 (장애로 비경제활동): 15.5%
#
#   - AGE 평균: 0.51 → 다섯 클러스터 중 가장 젊은 편
#
#   - EDUC 평균: 0.679 → 교육 수준 다소 낮음
#
# **Cluster 1: 우울증+불안 혼합군, 중간소득 여성 중심**
#   - GENDER: 38.4% 남성 → 여성이 다수
#
#   - CMPSERVICE: 95% 이용
#
#   - OPISERVICE: 6.6% → 외래서비스도 이용
#
#   - LIVARAG_2: 90.7% → 독립적 거주 형태
#
# **Cluster 2: 경증군, 고연령, 고교육, 남성 중심**
#   - AGE: 0.64 → 가장 연령 높음
#
#   - GENDER: 62.8% 남성
#
#   - SMISED_2 (정신질환 진단받음): 0.28% → 매우 낮음
#
# **Cluster 3: 조울증 고위험군, 중간연령, 성별 균형**
#   - EDUC: 0.750 → 교육 수준 가장 높음
#
# **Cluster 4: 불안장애 중심, 고연령+고교육, 인종 편향 뚜렷**
#   - EDUC: 0.744
#
#   - RACE_5: 75.4% → 가장 비율 높음
#
#   - SMISED_3: 30.4% → 사회문제 보유 비율 매우 높음
#
#
# ### 최종 요약: 배경 기반 클러스터 비교표
#
# | Cluster	| 핵심 프로파일 요약 |
# |---------|---------------------|
# |0	| 젊고 사회문제 많음, 행동·발달 문제 중심, 저소득 독립 거주|
# |1	| 우울+불안군, 여성 중심, 교육↑, 서비스 접근 양호 |
# |2	| 경증군, 고령 남성 중심, 주거 불안정 경향 |
# |3	| 조울증 중심, 교육수준↑, 여성이 다수, 상태 안정적 |
# |4	| 불안+사회문제 집단, 특정 인종 비율 높음, 서비스 접근 낮음 |

# %% [markdown]
# # **Step 5: 전략 A와 B 비교**
#
# - **사용 칼럼**: Step 2와 Step 3~4의 결과 활용.
# - **방법**:
#     - 전략 A(연관 규칙)에서 찾은 조합(예: DEPRESS+무직 → PTSD)과 전략 B(클러스터)의 질병+배경 패턴을 비교.
#     - 일치 여부는 공통된 질병 조합과 배경 변수의 유사성으로 판단.

# %%
# 클러스터 요약 정보 다시 계산
cluster_summary = data.groupby('cluster')[disease_columns].mean()

# 예시 비교: DEPRESSFLG와 ANXIETYFLG 값이 높은 클러스터가 SMISED_2와 관련된 연관 규칙과 일치하는지 확인
print("Comparing Strategy A (Rules) with Strategy B (Clusters):")
high_depress_anxiety_clusters = cluster_summary[(cluster_summary['DEPRESSFLG'] > 0.5) & (cluster_summary['ANXIETYFLG'] > 0.5)].index

if not high_depress_anxiety_clusters.empty:
    print("\nClusters with high DEPRESSFLG and ANXIETYFLG:")
    for cluster in high_depress_anxiety_clusters:
        smised_2_proportion = data[data['cluster'] == cluster]['SMISED_2'].mean()
        print(f"Cluster {cluster}: Proportion of SMISED_2 = {smised_2_proportion}")
else:
    print("\nNo clusters found with high DEPRESSFLG and ANXIETYFLG.")

# 전략 A에서 생성된 규칙 중 이 패턴과 일치하는 것이 있는지 확인
relevant_rules = background_to_disease_rules[
    background_to_disease_rules['antecedents'].str.contains('SMISED_2') &
    background_to_disease_rules['consequents'].str.contains('DEPRESSFLG|ANXIETYFLG')
]
print("\nRelevant Rules from Strategy A (SMISED_2 -> DEPRESSFLG or ANXIETYFLG):")
if not relevant_rules.empty:
    print(relevant_rules[['antecedents', 'consequents', 'lift']])
else:
    print("No matching rules found.")
